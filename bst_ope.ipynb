# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

class BST:
    def __init__(self):
        self.root = None

    def insert(self, root, data):
        if root is None:
            return Node(data)

        if data < root.data:
            root.left = self.insert(root.left, data)
        elif data > root.data:
            root.right = self.insert(root.right, data)

        return root

    def inorder(self, root):
        if root:
            self.inorder(root.left)
            print(root.data, end=" ")
            self.inorder(root.right)

    def find_min(self, root):
        while root.left:
            root = root.left
        return root

    def delete(self, root, data):
        if root is None:
            return None

        if data < root.data:
            root.left = self.delete(root.left, data)
        elif data > root.data:
            root.right = self.delete(root.right, data)
        else:
            if root.left is None:
                return root.right

            if root.right is None:
                return root.left

            successor = self.find_min(root.right)
            root.data = successor.data
            root.right = self.delete(root.right, successor.data)

        return root


# Create BST
bst = BST()
values = [50, 30, 70, 20, 40, 60, 80]

for value in values:
    bst.root = bst.insert(bst.root, value)

print("Before deletion:")
bst.inorder(bst.root)

bst.root = bst.delete(bst.root, 20)
print("\nAfter deleting 20:")
bst.inorder(bst.root)

bst.root = bst.delete(bst.root, 30)
print("\nAfter deleting 30:")
bst.inorder(bst.root)

bst.root = bst.delete(bst.root, 50)
print("\nAfter deleting 50:")
bst.inorder(bst.root)
# Out:
# Before deletion
# 20 30 40 50 60 70 80
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 7
#       3         self.data = data
#       4         self.left = None
#       5         self.right = None
#       6
# ----> 7 class BST:
#       8     def __init__(self):
#       9         self.root = None
#      10
#
# Cell In[3], line 80, in BST()
#      76     print("Before deletion")
#      77     bst.inorder(bst.root)
#      78
#      79     # Delete 20
# ---> 80     bst.root = bst.delete(bst.root, 20)
#      81
#      82     print("\nAfter deleting 20:")
#      83     bst.inorder(bst.root)
#
# AttributeError: 'BST' object has no attribute 'delete'
